# %%
# daretime : 날짜, 시간 관련 모듈
import datetime as dt

print("현재 시간 출력", dt.datetime.now())
# Out:
# 현재 시간 출력 2022-05-04 09:48:55.580237

# %%
print("현재 시간 출력", dt.datetime.now())
now = dt.datetime.now()
print(now.year,"년")
print(now.month,"월")
print(now.day,"일")
print(now.hour,"시")
print(now.minute,"분")
print(now.second,"초")
print()
# Out:
# 현재 시간 출력 2022-05-04 09:50:41.168402
# 2022 년
# 5 월
# 4 일
# 9 시
# 50 분
# 41 초

# %%
output = dt.datetime.now()
print("{}년 {}월 {}일 {}시 {}분 {}초".format(output.year,
                                        output.month,output.day,
                                      output.hour,output.minute,
                                      output.second))
# Out:
# 2022년 5월 4일 10시 14분 7초

# %%
# 시간 출력 방법
print("#시간을 포맷에 맞춰 출력하기")
output_a = now.strftime("%Y.%Y.%d %H.%M.%S")
output_b = "{}년 {}월 {}일 {}시 {}분 {}초".format(now.year,\
                                           now.month,\
                                           now.hour,\
                                           now.minute,\
                                           now.second)
output_c = now.strftime("%Y{} %m{} %d{} %H{} %M{} %S{}").format(*"년월일시분초")
print(output_a)
print(output_b)
print(output_c)
print()
# Out:
# #시간을 포맷에 맞춰 출력하기
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-f3d9c169a56b> in <module>
#       2 print("#시간을 포맷에 맞춰 출력하기")
#       3 output_a = now.strftime("%Y.%Y.%d %H.%M.%S")
# ----> 4 output_b = "{}년 {}월 {}일 {}시 {}분 {}초".format(now.year,\
#       5                                            now.month,\
#       6                                            now.hour,\
#
# IndexError: Replacement index 5 out of range for positional args tuple

# %%
import time

target = time.time() + 1
while time.time() < target:
    print("대기상태",time.time())
# Out:
# 대기상태 1651626270.679425
# 대기상태 1651626270.679425
# 대기상태 1651626270.679425
# 대기상태 1651626270.679425
# 대기상태 1651626270.679425
# 대기상태 1651626270.679425
# 대기상태 1651626270.679425
# 대기상태 1651626270.679425
# 대기상태 1651626270.679425
# 대기상태 1651626270.679425
# 대기상태 1651626270.679425
# 대기상태 1651626270.679425
# 대기상태 1651626270.679425
# 대기상태 1651626270.679425
# 대기상태 1651626270.679425
# 대기상태 1651626270.679425
# 대기상태 1651626270.679425
# 대기상태 1651626270.679425
# 대기상태 1651626270.679425
# 대기상태 1651626270.680422
# 대기상태 1651626270.680422
# 대기상태 1651626270.680422
# 대기상태 1651626270.680422
# 대기상태 1651626270.680422
# 대기상태 1651626270.680422
# 대기상태 1651626270.680422
# 대기상태 1651626270.680422
# 대기상태 1651626270.680422
# 대기상태 1651626270.680422
# 대기상태 1651626270.680422
# 대기상태 1651626270.680422
# 대기상태 1651626270.680422
# 대기상태 1651626270.680422
# 대기상태 1651626270.680422
# 대기상태 1651626270.680422
# 대기상태 1651626270.680422
# 대기상태 1651626270.680422
# 대기상태 1651626270.680422
# 대기상태 1651626270.680422
# ...

# %%
import time

print("지금부터 5초 동안 정지합니다")
time.sleep(5)
print("프로그램을 종료합니다")
# Out:
# 지금부터 5초 동안 정지합니다
# 프로그램을 종료합니다

# %%
# urllib 모듈
from urllib import request

target = request.urlopen("https://www.google.com")
print(target.read())
# Out:
# b'<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="ko"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="SppCSBj3zqXJ-YB04MHPKQ">(function(){window.google={kEI:\'-89xYrObGIuD2roPoby4iAE\',kEXPI:\'0,18167,1284369,56873,6059,206,2414,2390,925,1391,383,246,5,1354,4013,1237,1122516,1197705,303257,77528,16115,28684,17572,4859,1361,9291,3023,17585,4020,978,13228,3847,4192,6430,7432,15309,5081,1594,1278,2742,149,1103,840,1986,211,4100,3514,606,2023,1777,520,14670,3227,2845,7,4773,826,11851,16320,1850,15757,3,257,89,230,6459,149,13975,4,1528,2304,6463,576,25073,2658,7357,13658,4437,16786,5800,2557,4094,4052,3,3541,1,14261,27893,2,14022,1931,5589,744,5852,11623,5679,1021,2380,2719,18260,2,6,7755,4567,6259,2960,3757,16701,1252,5835,14967,1555,2778,19,6071,1394,445,2,2,1,3449,21329,1417,1,436,8155,5124,5,1453,799,189
# ...

# %%
# !pip install beautifulsoup4

# %%
# url 데이터를 다루기 위해 bs4의 BeautifulSoup 을 import
from bs4 import BeautifulSoup

# %%
html_doc = """<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

# %%
print(html_doc)
# Out:
# <html><head><title>The Dormouse's story</title></head>
# <body>
# <p class="title"><b>The Dormouse's story</b></p>
#
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
# <a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
# <a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
#
# <p class="story">...</p>

# %%
soup = BeautifulSoup(html_doc,'html.parser')
soup
# Out:
# <html><head><title>The Dormouse's story</title></head>
# <body>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body></html>

# %%
# 각 tag 의 데이터 검색
print(soup.title)
print(soup.title.name) # tag 의 이름
print(soup.title.parent) # 부모의 tag
print(soup.title.string) # title의 데이터
# Out:
# <title>The Dormouse's story</title>
# title
# <head><title>The Dormouse's story</title></head>
# The Dormouse's story

# %%
print(soup.p)
print(soup.p['class']) # 하나만 검색
print()
# 모든 p 태그를 검색
print(soup.find_all('p')) # 'p' 태그 검색 후 리스트로 반환
print()
print(soup.find('a')) # 처음 나오는 a 태그 하나만 검색
print()
# id = 'link2' 를 검색
print(soup.find(id="link2"))
# Out:
# <p class="title"><b>The Dormouse's story</b></p>
# ['title']
#
# [<p class="title"><b>The Dormouse's story</b></p>, <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>, <p class="story">...</p>]
#
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
#
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# http://example.com/elsie
# http://example.com/lacie
# http://example.com/tillie

# %%
soup.get_text()
# Out:
# "The Dormouse's story\n\nThe Dormouse's story\nOnce upon a time there were three little sisters; and their names were\nElsie,\nLacie and\nTillie;\nand they lived at the bottom of a well.\n...\n"

# %%
tag = BeautifulSoup('<b id="boldest">bold</b>', 'html.parser').b
print(tag['id']) # 속성의 값
print(tag.text)
# Out:
# boldest
# bold

# %%
tag.attrs
# Out:
# {'id': 'boldest'}

# %%
tag['another-attribute'] = 1
tag.attrs
# Out:
# {'id': 'boldest', 'another-attribute': 1}

# %%
# 설치가 안된 경우 실행
# pip install flask

# %%
# 웹 프레임워크 : flask
from flask import Flask

# %%
# 함수 데코레이터
# @로 시작하면 데코레이터
def test(function):
    print(function)
    def wrapper():
        print("wrapper 시작")
        function()
        print("wrapper end")
    return wrapper

# 데코레이터 함수 생성 
@test
def hello():
    print("hello")
    
hello() #함수 호출
# Out:
# <function hello at 0x00000243B1C08CA0>
# wrapper 시작
# hello
# wrapper end

# %%
hello()
# Out:
# hello
